# %% [markdown]
# <h1 style="color: green;">Home task : Natural Language Toolkit (NLTK)
# </h1>

# %%
from nltk.corpus import gutenberg 
import nltk

# %%
moby_raw = gutenberg.raw('melville-moby_dick.txt')

# %% [markdown]
# <h3 style="color: green;">Example 1
# </h3>

# %% [markdown]
# How many tokens (words and punctuation symbols) are in `moby_raw`?<br>*This function should return an integer.*

# %%
def example_one():
    from nltk.tokenize import word_tokenize
    return len(word_tokenize(moby_raw))

# %% [markdown]
# <h3 style="color: blue;">Check result
# </h3>

# %%
print ('{:,}'.format(example_one()))
# Out:
# 255,222

# %% [markdown]
# <h3 style="color: green;">Example 2
# </h3>

# %% [markdown]
# How many unique tokens (unique words and punctuation) does `moby_raw` have?<br>*This function should return an integer.*

# %%
def example_two():    
    return len(set(nltk.word_tokenize(moby_raw)))

# %% [markdown]
# <h3 style="color: blue;">Check result
# </h3>

# %%
print ('{:,}'.format(example_two()))
# Out:
# 20,639

# %% [markdown]
# <h3 style="color: green;">Example 3
# </h3>

# %% [markdown]
# After lemmatizing the verbs, how many unique tokens does `moby_raw` have?<br>*This function should return an integer.*

# %%
from nltk.stem import WordNetLemmatizer

def example_three():
    lemmatizer = WordNetLemmatizer()
    lemmatized = [lemmatizer.lemmatize(w,'v') for w in nltk.word_tokenize(moby_raw)]
    return len(set(lemmatized))

# %% [markdown]
# <h3 style="color: blue;">Check result
# </h3>

# %%
print ('{:,}'.format(example_three()))
# Out:
# 16,908

# %% [markdown]
# <h3 style="color: green;">Question 1
# </h3>

# %% [markdown]
# What is the lexical diversity of the given text input? (i.e. ratio of unique tokens to the total number of tokens)<br>*This function should return a float.*

# %%
def answer_one(moby_raw):
    total = example_one()
    unique = example_two()
    return unique/total

# %% [markdown]
# <h3 style="color: blue;">Check result
# </h3>

# %%
answer_one(moby_raw)
# Out:
# 0.08086685317096488

# %% [markdown]
# <h3 style="color: blue;">Expected Output
# </h3>

# %% [markdown]
# `0.08139566804842562`

# %% [markdown]
# <h3 style="color: green;">Question 2
# </h3>

# %% [markdown]
# What percentage of tokens is 'whale'or 'Whale'?<br>*This function should return a float.*

# %%
from nltk.tokenize import word_tokenize

def answer_two():  
    tokens = word_tokenize(moby_raw)
    whale_count = tokens.count("whale") + tokens.count("Whale")
    total_count = len(tokens)
    return 100 * whale_count / total_count

# %% [markdown]
# <h3 style="color: blue;">Check result
# </h3>

# %%
answer_two()
# Out:
# 0.4157165134667074

# %% [markdown]
# <h3 style="color: blue;">Expected Output
# </h3>

# %% [markdown]
# `0.4125668166077752`

# %% [markdown]
# <h3 style="color: green;">Question 3
# </h3>

# %% [markdown]
# What are the 20 most frequently occurring (unique) tokens in the text? What is their frequency?<br>
# *This function should return a list of 10 tuples where each tuple is of the form `(token, frequency)`. The list should be sorted in descending order of frequency.*

# %%
from nltk import FreqDist

def answer_three():
    tokens = word_tokenize(moby_raw)
    fdist = FreqDist(tokens)
    return fdist.most_common(10)

# %% [markdown]
# <h3 style="color: blue;">Check result
# </h3>

# %%
answer_three()
# Out:
# [(',', 19204),
#  ('the', 13715),
#  ('.', 7306),
#  ('of', 6513),
#  ('and', 6010),
#  ('a', 4545),
#  ('to', 4515),
#  (';', 4173),
#  ('in', 3908),
#  ('that', 2981)]

# %% [markdown]
# <h3 style="color: blue;">Expected Output
# </h3>

# %% [markdown]
# `[(',', 19204),  ('the', 13715),  ('.', 7308),  ('of', 6513),  ('and', 6010),  ('a', 4545),  ('to', 4515),  (';', 4173),  ('in', 3908),  ('that', 2978)]`

# %% [markdown]
# <h3 style="color: green;">Question 4
# </h3>

# %% [markdown]
# What tokens have a length of greater than 5 and frequency of more than 150?<br>
# *This function should return a sorted list of the tokens that match the above constraints. To sort your list, use `sorted()`*

# %%
def answer_four():
    tokens = word_tokenize(moby_raw)
    fdist = FreqDist(tokens)
    return sorted([w for w in fdist if len(w) > 5 and fdist[w] > 150])

# %% [markdown]
# <h3 style="color: blue;">Check result
# </h3>

# %%
print(answer_four())
# Out:
# ['Captain', 'Pequod', 'Queequeg', 'Starbuck', 'almost', 'before', 'himself', 'little', 'seemed', 'should', 'though', 'through', 'whales', 'without']

# %% [markdown]
# <h3 style="color: blue;">Expected Output
# </h3>

# %% [markdown]
# `['Captain', 'Pequod', 'Queequeg', 'Starbuck', 'almost', 'before', 'himself', 'little', 'seemed', 'should', 'though', 'through', 'whales', 'without']`

# %% [markdown]
# <h3 style="color: green;">Question 5
#
# </h3>

# %% [markdown]
# Find the longest word in text1 and that word's length.<br>
# *This function should return a tuple `(longest_word, length)`*

# %%
def answer_five():
    tokens = word_tokenize(moby_raw)
    longest_word = ""
    for word in tokens:
        if len(word) > len(longest_word):
            longest_word = word 
    return (longest_word, len(longest_word))

# %% [markdown]
# <h3 style="color: blue;">Check result
# </h3>

# %%
answer_five()
# Out:
# ("twelve-o'clock-at-night", 23)

# %% [markdown]
# <h3 style="color: blue;">Expected Output
# </h3>

# %% [markdown]
# `("twelve-o'clock-at-night", 23)`

# %% [markdown]
# <h3 style="color: green;">Question 6
# </h3>

# %% [markdown]
# What unique words have a frequency of more than 2000? What is their frequency?<br>
# *This function should return a list of tuples of the form `(frequency, word)` sorted in descending order of frequency.*

# %%
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import nltk

def answer_six():
    tokens = word_tokenize(moby_raw)
    fdist = FreqDist(tokens)
    result = sorted(
        [(token, freq) for token, freq in fdist.items() if freq > 2000 and token.isalpha()],
        key=lambda x: x[1],
        reverse=True
    )
    return result

# %% [markdown]
# <h3 style="color: blue;">Check result
# </h3>

# %%
answer_six()
# Out:
# [('the', 13715),
#  ('of', 6513),
#  ('and', 6010),
#  ('a', 4545),
#  ('to', 4515),
#  ('in', 3908),
#  ('that', 2981),
#  ('his', 2459),
#  ('it', 2206),
#  ('I', 2121)]

# %% [markdown]
# <h3 style="color: blue;">Expected Output
# </h3>

# %% [markdown]
# `[(13715, 'the'), (6513, 'of'), (6010, 'and'), (4545, 'a'), (4515, 'to'), (3908, 'in'), (2978, 'that'), (2459, 'his'), (2196, 'it'), (2097, 'I')]`

# %% [markdown]
# <h3 style="color: green;">Question 7
# </h3>

# %% [markdown]
# What is the average number of tokens per sentence?<br>
# *This function should return a float.*

# %%
from nltk.tokenize import sent_tokenize,word_tokenize
import numpy as np

# %%
def answer_seven():
    tokens = word_tokenize(moby_raw)
    sentences = sent_tokenize(moby_raw)
    return len(tokens)/len(sentences)

# %% [markdown]
# <h3 style="color: blue;">Check result
# </h3>

# %%
print(answer_seven())
# Out:
# 25.90560292326431

# %% [markdown]
# <h3 style="color: blue;">Expected Output
# </h3>

# %% [markdown]
# `25.881952902963864`

# %% [markdown]
# <h3 style="color: green;">Question 8
# </h3>

# %% [markdown]
# What are the 5 most frequent parts of speech in this text? What is their frequency?<br>
# *This function should return a list of tuples of the form `(part_of_speech, frequency)` sorted in descending order of frequency.*

# %%
from nltk import pos_tag
from nltk.tokenize import word_tokenize
def answer_eight():
    tokens = word_tokenize(moby_raw)
    tagged_tokens = pos_tag(tokens)
    fdist = FreqDist(tag for word, tag in tagged_tokens)
    return fdist.most_common(5)

# %% [markdown]
# <h3 style="color: blue;">Check result
# </h3>

# %%
print(answer_eight())
# Out:
# [('NN', 32722), ('IN', 28659), ('DT', 25885), (',', 19204), ('JJ', 17598)]

# %% [markdown]
# <h3 style="color: blue;">Expected Output
# </h3>

# %% [markdown]
# `[('NN', 32730), ('IN', 28657), ('DT', 25867), (',', 19204), ('JJ', 17620)]`

# %% [markdown]
# <h3 style="color: green;">Question 9
# </h3>

# %% [markdown]
# Create spelling recommender, that take a list of misspelled words and recommends a correctly spelled word for every word in the list.<br>
#
# For every misspelled word, the recommender should find find the word in `correct_spellings` that has the shortest `edit distance` (you may need to use `nltk.edit_distance(word_1, word_2, transpositions=True))`, and starts with the same letter as the misspelled word, and return that word as a recommendation.<br>
#
# Recommender should provide recommendations for the three words: `['cormulent', 'incendenece', 'validrate']`.
# *This function should return a list of length three: `['cormulent_reccomendation', 'incendenece_reccomendation', 'validrate_reccomendation']`.*

# %%
from nltk.corpus import words
from nltk.metrics.distance import edit_distance
import nltk

# %%
def answer_nine(default_words=['cormulent', 'incendenece', 'validrate']):
    correct_spellings = words.words()
    recommendations = []

    for word in default_words:
        candidates = [i for i in correct_spellings if i[0] == word[0]]
        closest = min(candidates, key=lambda w: edit_distance(word, w))
        recommendations.append(closest)
        
    return recommendations

# %% [markdown]
# <h3 style="color: blue;">Check result
# </h3>

# %%
answer_nine()
# Out:
# ['corpulent', 'intendence', 'validate']

# %% [markdown]
# <h3 style="color: blue;">Expected Output
# </h3>

# %% [markdown]
# `['corpulent', 'intendence', 'validate']`
